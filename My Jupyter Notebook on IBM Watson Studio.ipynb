# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Elena Fernández Gutiérrez </b> <br> Nuclear Engineer

# %% [markdown]
# <i> I am interested in data science because I read a lot about it and do not know exactly what it is. I like all things related with programming and I do not use it since I was in school because my current work do not need it.</i>

# %% [markdown]
# ### This is a simple code to represent how the Jupyter Notebook works

# %%
A=[[2,4,5],[-3,6,5],[4,-7,1]]
print("A=",A)
B=A*2
print("B=",B)
# Out:
# A= [[2, 4, 5], [-3, 6, 5], [4, -7, 1]]
# B= [[2, 4, 5], [-3, 6, 5], [4, -7, 1], [2, 4, 5], [-3, 6, 5], [4, -7, 1]]

# %% [markdown]
# <i>Recipe</i> <br> <ol> <li>Flour</li> <li>Eggs</li> <li>Lemon</li> <li>Sugar</li>
# </ol> <br>
# <ul> <li>Whisk the eggs</li> <li>Mix the eggs with the sugar</li>  <li>Add the flor to the mix</li> </ul> <br>
# <a href="https://perrhijos.com.mx/wp-content/uploads/2019/04/IMG_1418.png">Dog with a gift</a> <br>

# %% [markdown]
# | Ingredient | grams/units |
# | ------ | ------ |
# | Flour | 950 gr |
# | Eggs | 3 units |
# |Lemon | 1 unit |
# |Sugar | 340 gr |
